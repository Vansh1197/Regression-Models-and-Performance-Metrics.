# %% [markdown]
# Question 1 : What is Simple Linear Regression (SLR)? Explain its purpose.
#  >> Simple Linear Regression (SLR) is a statistical method that examines the relationship between two variables: one independent and one dependent. It represents this relationship with a straight-line equation
# >>𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ε, where
# 𝛽
# 0
# β
# 0
# 	​
#
#  >> is the intercept,
# >> 𝛽
# >> 1
# >> β
# >> 1
# 	​
#
#  >> the slope, and
# 𝜀
# >> ε the error term. The main purpose of SLR is to predict the dependent variable’s value from the independent variable and to measure the strength and direction of their relationship.

# %% [markdown]
# Question 2: What are the key assumptions of Simple Linear Regression?
#  >> The key assumptions of Simple Linear Regression (SLR) are:
#
#  >>Linearity: The relationship between the independent variable
# 𝑋
# X and the dependent variable
# 𝑌
# Y is linear.
#
# >> Independence: The observations are independent of each other.
#
# >> Homoscedasticity: The variance of the error terms (
# 𝜀
# ε) is constant across all values of
# 𝑋
# X.
#
# >> Normality of Errors: The error terms are normally distributed.
#
# >> No Multicollinearity: Since SLR involves only one predictor, this assumption implies that
# 𝑋
# X is not a constant and has variation.

# %% [markdown]
# Question 3: Write the mathematical equation for a simple linear regression model and
# explain each term.
#  >> The mathematical equation for a Simple Linear Regression (SLR) model is:
#
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ε
#
# Explanation of each term:
#
# 𝑌
# Y – The dependent variable (response), whose value we want to predict or explain.
#
# 𝑋
# X – The independent variable (predictor), used to explain or predict changes in
# 𝑌
# Y.
#
# 𝛽
# 0
# β
# 0
# 	​
#
#  – The intercept, representing the expected value of
# 𝑌
# Y when
# 𝑋
# =
# 0
# X=0.
#
# 𝛽
# 1
# β
# 1
# 	​
#
#  – The slope coefficient, indicating the change in
# 𝑌
# Y for a one-unit change in
# 𝑋
# X.
#
# 𝜀
# ε – The error term, accounting for random variation or factors not captured by
# 𝑋
# X.
#
# This equation defines a straight-line relationship between
# 𝑋
# X and
# 𝑌
# Y, where the slope and intercept describe the line’s position and direction.

# %% [markdown]
# Question 4: Provide a real-world example where simple linear regression can be
# applied.
#  >> A real-world example of Simple Linear Regression is predicting a person’s weight based on their height. In this case, height (
# 𝑋
# X) is the independent variable, and weight (
# 𝑌
# Y) is the dependent variable. By analyzing data from several individuals, a regression line can be fitted to show how weight tends to increase with height. This model can then be used to predict a person’s weight given their height or to understand the relationship between these two variables.

# %% [markdown]
# Question 5: What is the method of least squares in linear regression?
#  >> The method of least squares in linear regression is a technique used to find the best-fitting line through a set of data points by minimizing the sum of the squared differences between the observed values and the values predicted by the line.
#
# In other words, it chooses the regression line
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X such that the total of the squared residuals
# (
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# )
# 2
# (Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# )
# 2
#  is as small as possible, where
# 𝑌
# 𝑖
# Y
# i
# 	​
#
#  is the actual value and
# 𝑌
# 𝑖
# ^
# Y
# i
# 	​
#
# ^
# 	​
#
#  is the predicted value.
#
# This method ensures that the fitted line represents the data as accurately as possible, reducing overall prediction error.

# %% [markdown]
# Question 6: What is Logistic Regression? How does it differ from Linear Regression?
#  >> Logistic Regression is a statistical method used to model the relationship between independent variables and a categorical dependent variable, typically binary (e.g., 0 or 1). It predicts the probability of an event occurring using the logistic (sigmoid) function, ensuring outputs range between 0 and 1. Unlike Linear Regression, which predicts continuous values using a straight-line relationship, Logistic Regression predicts probabilities and uses a nonlinear S-shaped curve. It also relies on maximum likelihood estimation instead of the least squares method used in Linear Regression.

# %% [markdown]
# Question 7: Name and briefly describe three common evaluation metrics for regression
# models.
#  >> Three common evaluation metrics for regression models are:
#
# >> Mean Absolute Error (MAE): Measures the average absolute difference between predicted and actual values. It shows how far predictions are, on average, from the true values.
#
# >> Mean Squared Error (MSE): Calculates the average of the squared differences between predicted and actual values, giving more weight to larger errors.
#
# >> R-squared (Coefficient of Determination): Indicates how well the model explains the variability of the dependent variable, with values closer to 1 showing a better fit.

# %% [markdown]
# Question 8: What is the purpose of the R-squared metric in regression analysis?
#  >> The R-squared metric in regression analysis measures the proportion of the variance in the dependent variable that is explained by the independent variable(s). It ranges from 0 to 1, where 0 indicates the model explains none of the variability and 1 indicates it explains all. R-squared is used to assess the goodness of fit of a regression model and to compare models, but it does not imply causation and can be artificially increased by adding more predictors. In multiple regression, adjusted R-squared is preferred as it accounts for the number of variables in the model.

# %% [markdown]
# Question 9: Write Python code to fit a simple linear regression model using scikit-learn
# and print the slope and intercept.
# (Include your Python code and output in the code box below.)
#  >>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Independent variable
y = np.array([2, 4, 5, 4, 5])  # Dependent variable

# Create a linear regression model
model = LinearRegression()

# Fit the model
model.fit(X, y)

# Print the slope and intercept
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 0.6
# Intercept: 2.2

# %% [markdown]
# Question 10: How do you interpret the coefficients in a simple linear regression model?
#  >> In a simple linear regression model, the coefficients represent the relationship between the independent variable
# 𝑋
# X and the dependent variable
# 𝑌
# Y. The intercept (
# 𝑏
# 0
# b
# 0
# 	​
#
# ) is the expected value of
# 𝑌
# Y when
# 𝑋
# =
# 0
# X=0, and the slope (
# 𝑏
# 1
# b
# 1
# 	​
#
# ) indicates the change in
# 𝑌
# Y for a one-unit increase in
# 𝑋
# X. A positive slope means
# 𝑌
# Y increases as
# 𝑋
# X increases, while a negative slope means
# 𝑌
# Y decreases as
# 𝑋
# X increases. Essentially, the coefficients quantify how changes in the predictor affect the outcome.
